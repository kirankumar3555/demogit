# %%
import pandas as pd

# %%
d_1={'Name':["ravi","hari","shahid","devi"],
    'Age':[22,25,21,20],
     'Gender':['M','F','F','M'],
     'Place':['Hyd','Del','Mum','Blr']
    }
type(d_1['Name'])
# Out:
# list

# %%
pd.DataFrame(d_1) #creating a dataframe from dictionary
# Out:
#      Name  Age Gender Place
# 0    ravi   22      M   Hyd
# 1    hari   25      F   Del
# 2  shahid   21      F   Mum
# 3    devi   20      M   Blr

# %%
Name=['ravi','hari','shahid','devi']  #creating dataframe using lists
Age=[22,25,21,20]
Gender=['M','F','F','M']
Place=['Hyd','Del','Mum','Blr']
zip1=list(zip(Name,Age,Gender,Place)) #zip creates the row which assigns the corresponding values of each people that we desire, it's not mandatory to use list(zip()) we can directly use pd.DataFrame(zip())
gf=pd.DataFrame(zip1,columns=['Name','Age','Gender','Place'])

# %%
list_1=[['ravi','hari','shahid','devi'] ,[22,25,21,20]] #we should not create a dataframe in this way by using lists.it takes each list as a row rather than column. 
pd.DataFrame(list_1)
# Out:
#       0     1       2     3
# 0  ravi  hari  shahid  devi
# 1    22    25      21    20

# %%
path='D:/Data/datasets/Data/' #absolute path

# %%
h=pd.read_csv(path+'loans data.csv') #reading a file into pandas
h
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
h.shape
# Out:
# (2500, 15)

# %%
type(h)
# Out:
# pandas.core.frame.DataFrame

# %%
pwd #gives the present working directory
# Out:
# 'C:\\Users\\Media_Box'

# %%
h.head(10) #gives the first 10 rows h.head() gives the first 5 rows
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  81174.0            20000                      20000         8.90%
# 1  99592.0            19200                      19200        12.12%
# 2  80059.0            35000                      35000        21.98%
# 3  15825.0            10000                       9975         9.99%
# 4  33182.0            12000                      12000        11.71%
# 5  62403.0             6000                       6000        15.31%
# 6  48808.0            10000                      10000         7.90%
# 7  22090.0            33500                      33450        17.14%
# 8  76404.0            14675                      14675        14.33%
# 9  15867.0                .                       7000         6.91%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# ...

# %%
h.columns #gives all the column names
type(h.columns)
kl=list(h.columns)
kl
# Out:
# ['ID',
#  'Amount.Requested',
#  'Amount.Funded.By.Investors',
#  'Interest.Rate',
#  'Loan.Length',
#  'Loan.Purpose',
#  'Debt.To.Income.Ratio',
#  'State',
#  'Home.Ownership',
#  'Monthly.Income',
#  'FICO.Range',
#  'Open.CREDIT.Lines',
#  'Revolving.CREDIT.Balance',
#  'Inquiries.in.the.Last.6.Months',
#  'Employment.Length']

# %%
h.dtypes #to find the datatype of each column object = string, in numpy if we add a string to numeric then it makes all the numerics to strings data types
# Out:
# ID                                float64
# Amount.Requested                   object
# Amount.Funded.By.Investors         object
# Interest.Rate                      object
# Loan.Length                        object
# Loan.Purpose                       object
# Debt.To.Income.Ratio               object
# State                              object
# Home.Ownership                     object
# Monthly.Income                    float64
# FICO.Range                         object
# Open.CREDIT.Lines                  object
# Revolving.CREDIT.Balance           object
# Inquiries.in.the.Last.6.Months    float64
# Employment.Length                  object
# dtype: object

# %%
h.info() #it gives how many non null values are there in each column which indirectly gives idea about the null values too
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
# ID                                2499 non-null float64
# Amount.Requested                  2499 non-null object
# Amount.Funded.By.Investors        2499 non-null object
# Interest.Rate                     2500 non-null object
# Loan.Length                       2499 non-null object
# Loan.Purpose                      2499 non-null object
# Debt.To.Income.Ratio              2499 non-null object
# State                             2499 non-null object
# Home.Ownership                    2499 non-null object
# Monthly.Income                    2497 non-null float64
# FICO.Range                        2500 non-null object
# Open.CREDIT.Lines                 2496 non-null object
# Revolving.CREDIT.Balance          2497 non-null object
# Inquiries.in.the.Last.6.Months    2497 non-null float64
# Employment.Length                 2422 non-null object
# ...

# %%
h.describe() # only it gives the float value's statistics like mean,standard deviation,quantiles,maximum,minimum
# Out:
#                   ID  Monthly.Income  Inquiries.in.the.Last.6.Months
# count    2499.000000     2497.000000                     2497.000000
# mean    51643.325330     5689.716608                        0.906688
# std     30053.637661     3963.568002                        1.231149
# min        10.000000      588.500000                        0.000000
# 25%     26570.500000     3500.000000                        0.000000
# 50%     50673.000000     5000.000000                        0.000000
# 75%     77583.000000     6800.000000                        1.000000
# max    104202.000000   102750.000000                        9.000000

# %%
h['ID'] # To extract one column or subsetting one column
type(h['ID']) # one single column is known as pandas series 
list(h['ID']) #coverting one panda series or one column to list
# Out:
# [81174.0,
#  99592.0,
#  80059.0,
#  15825.0,
#  33182.0,
#  62403.0,
#  48808.0,
#  22090.0,
#  76404.0,
#  15867.0,
#  94971.0,
#  36911.0,
#  41200.0,
#  83869.0,
#  53853.0,
#  21399.0,
#  62127.0,
#  23446.0,
#  44987.0,
#  17977.0,
#  86099.0,
#  99483.0,
#  28798.0,
#  24168.0,
#  10356.0,
#  46027.0,
#  2238.0,
#  65278.0,
#  4227.0,
#  50182.0,
#  87023.0,
#  46120.0,
#  30756.0,
#  94582.0,
#  457.0,
#  96536.0,
#  39591.0,
#  78862.0,
#  54619.0,
#  101798.0,
#  98029.0,
#  95579.0,
#  4868.0,
#  26822.0,
#  98445.0,
#  14958.0,
#  14754.0,
#  34501.0,
#  26888.0,
#  81759.0,
#  10825.0,
#  16667.0,
#  92046.0,
#  88279.0,
#  17218.0,
#  82406.0,
#  17143.0,
#  27486.0,
#  96613.0,
#  6263.0,
#  29283.0,
#  99766.0,
#  85893.0,
#  98972.0,
#  44054.0,
#  51948.0,
#  48676.0,
#  82294.0,
#  20328.0,
#  71489.0,
#  43203.0,
#  48319.0,
#  5367.0,
#  83768.0,
#  88084.0,
#  101540.0,
#  9664.0,
#  1494.0,
#  61703.0,
#  61576.0,
#  21993.0,
#  58359.0,
#  67335.0,
# ...

# %%
h[['ID','Amount.Requested']] # subsetting more than one columns and this gives a dataframe
# Out:
#            ID Amount.Requested
# 0     81174.0            20000
# 1     99592.0            19200
# 2     80059.0            35000
# 3     15825.0            10000
# 4     33182.0            12000
# ...       ...              ...
# 2495  23735.0            30000
# 2496  65882.0            16000
# 2497  55610.0            10000
# 2498  38576.0             6000
# 2499   3116.0             9000
#
# [2500 rows x 2 columns]

# %%
h.iloc[:,0] # subsetting one column with index and all rows
h.iloc[0,:] # subsetting one row with index and all columns
h.iloc[:,0:3] # subsetting all rows and first three columns
h.iloc[:,[0,2,5]]
# Out:
#            ID Amount.Funded.By.Investors        Loan.Purpose
# 0     81174.0                      20000  debt_consolidation
# 1     99592.0                      19200  debt_consolidation
# 2     80059.0                      35000  debt_consolidation
# 3     15825.0                       9975  debt_consolidation
# 4     33182.0                      12000         credit_card
# ...       ...                        ...                 ...
# 2495  23735.0                      29950  debt_consolidation
# 2496  65882.0                      16000    home_improvement
# 2497  55610.0                      10000  debt_consolidation
# 2498  38576.0                       6000      major_purchase
# 2499   3116.0                    5242.75  debt_consolidation
#
# [2500 rows x 3 columns]

# %%
h.iloc[:,[0,1,4]] # subsetting all rows and 0 ,1 and 4th column
# Out:
#            ID Amount.Requested Loan.Length
# 0     81174.0            20000   36 months
# 1     99592.0            19200   36 months
# 2     80059.0            35000   60 months
# 3     15825.0            10000   36 months
# 4     33182.0            12000   36 months
# ...       ...              ...         ...
# 2495  23735.0            30000   60 months
# 2496  65882.0            16000   60 months
# 2497  55610.0            10000   36 months
# 2498  38576.0             6000   36 months
# 2499   3116.0             9000   36 months
#
# [2500 rows x 3 columns]

# %%
h.iloc[[0,2,4],[0,2,4]] #subsetting 0,2 and 4 th row along with 0,2 and 4th column
# Out:
#         ID Amount.Funded.By.Investors Loan.Length
# 0  81174.0                      20000   36 months
# 2  80059.0                      35000   60 months
# 4  33182.0                      12000   36 months

# %%
bn=h['Home.Ownership']

# %%
bn.unique() # to get unique values present in the columnvariable
# Out:
# array(['MORTGAGE', 'RENT', 'OWN', 'OTHER', 'NONE', nan], dtype=object)

# %%
bn.value_counts() # count the value of each unique value present in the column
# Out:
# MORTGAGE    1147
# RENT        1146
# OWN          200
# OTHER          5
# NONE           1
# Name: Home.Ownership, dtype: int64

# %%
h.value_counts() #value_countsdoesnot work on a dataframe
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-9003972a0cc3> in <module>
# ----> 1 h.value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
h['Home.Ownership']=='MORTGAGE' # to find where in the column of house ownership mortgage present
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 2495     True
# 2496    False
# 2497     True
# 2498    False
# 2499    False
# Name: Home.Ownership, Length: 2500, dtype: bool

# %%
gf 
gf.iloc[0,:]
gf.iloc[[0,2],:]
# Out:
#      Name  Age Gender Place
# 0    ravi   22      M   Hyd
# 2  shahid   21      F   Mum

# %%
gf.iloc[[True,False,True,False],:] # subsetting the rows by using true and false or subsetting the rows by using conditions
gf.loc[[True,False,True,False],:] # iloc can be used for both indexing as well as true and false or boolean. where as loc is used for subsetting list using boolean or true and false.but generally we use loc to subset the list using the boolean
# Out:
#      Name  Age Gender Place
# 0    ravi   22      M   Hyd
# 2  shahid   21      F   Mum

# %%
h[h['Home.Ownership']=='MORTGAGE'] # SUBSETTING HOME.OWNERSHIP == MORTGAGE ROWS
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 7     22090.0            33500                      33450        17.14%
# ...       ...              ...                        ...           ...
# 2492    925.0             6400                       6350        10.08%
# 2493  74047.0            30000                      30000        23.28%
# 2494  49957.0            24000                      23975        14.65%
# 2495  23735.0            30000                      29950        16.77%
# 2497  55610.0            10000                      10000        13.99%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
nh=h['Home.Ownership'] # subsetting the Home ownership of mortgage
nh1=nh=='MORTGAGE'
nh2=h.loc[nh1,:]

# %%
nh2['Home.Ownership'].unique()
# Out:
# array(['MORTGAGE'], dtype=object)

# %%
nh3=nh2['Monthly.Income']
nh4=nh3>5000
nh5=nh1 & nh4
h.loc[nh5,:]
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 2     80059.0            35000                      35000        21.98%
# 7     22090.0            33500                      33450        17.14%
# 12    41200.0            28000                      27975        21.67%
# 20    86099.0            22000                      21975        21.98%
# ...       ...              ...                        ...           ...
# 2485  13070.0            25000                      24950        10.75%
# 2492    925.0             6400                       6350        10.08%
# 2493  74047.0            30000                      30000        23.28%
# 2494  49957.0            24000                      23975        14.65%
# 2495  23735.0            30000                      29950        16.77%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
nh8=h[(h['Home.Ownership']=='MORTGAGE') & (h['Monthly.Income']>5000)] 
nh8
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 2     80059.0            35000                      35000        21.98%
# 7     22090.0            33500                      33450        17.14%
# 12    41200.0            28000                      27975        21.67%
# 20    86099.0            22000                      21975        21.98%
# ...       ...              ...                        ...           ...
# 2485  13070.0            25000                      24950        10.75%
# 2492    925.0             6400                       6350        10.08%
# 2493  74047.0            30000                      30000        23.28%
# 2494  49957.0            24000                      23975        14.65%
# 2495  23735.0            30000                      29950        16.77%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
nh6['Home.Ownership'].value_counts()
# Out:
# MORTGAGE    686
# Name: Home.Ownership, dtype: int64

# %%
min(nh6['Monthly.Income']) # to check whether subsetting according to the condition is right or not,here we are subsetting the monthly incomes greater than 5000
# Out:
# 5002.33

# %%
h1=h.drop(['FICO.Range','Employment.Length'],axis=1) # inplace=True ,returns the new dataframe which it removed the columns that we have mentioned.so it reduces our effort of again storing the new dataframe that was formed after dropping the columns.
h1.columns
# Out:
# Index(['ID', 'Amount.Requested', 'Amount.Funded.By.Investors', 'Interest.Rate',
#        'Loan.Length', 'Loan.Purpose', 'Debt.To.Income.Ratio', 'State',
#        'Home.Ownership', 'Monthly.Income', 'Open.CREDIT.Lines',
#        'Revolving.CREDIT.Balance', 'Inquiries.in.the.Last.6.Months'],
#       dtype='object')

# %%
nh7.reset_index(inplace=True) # changing the row indexes to the number of rows as mentioned 686
nh7
# Out:
#      index       ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0        0  81174.0            20000                      20000         8.90%
# 1        2  80059.0            35000                      35000        21.98%
# 2        7  22090.0            33500                      33450        17.14%
# 3       12  41200.0            28000                      27975        21.67%
# 4       20  86099.0            22000                      21975        21.98%
# ..     ...      ...              ...                        ...           ...
# 681   2485  13070.0            25000                      24950        10.75%
# 682   2492    925.0             6400                       6350        10.08%
# 683   2493  74047.0            30000                      30000        23.28%
# 684   2494  49957.0            24000                      23975        14.65%
# 685   2495  23735.0            30000                      29950        16.77%
#
# ...

# %%
nh8.reset_index(inplace=True,drop=True) #deletes the previous index that we got while reseting the index that means we are only keeping the index of reset index and deleting the previous index
nh8
# Out:
#           ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0    81174.0            20000                      20000         8.90%
# 1    80059.0            35000                      35000        21.98%
# 2    22090.0            33500                      33450        17.14%
# 3    41200.0            28000                      27975        21.67%
# 4    86099.0            22000                      21975        21.98%
# ..       ...              ...                        ...           ...
# 681  13070.0            25000                      24950        10.75%
# 682    925.0             6400                       6350        10.08%
# 683  74047.0            30000                      30000        23.28%
# 684  49957.0            24000                      23975        14.65%
# 685  23735.0            30000                      29950        16.77%
#
#     Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# ...

# %%
#in python index means rownames so in drop parameter above we didn't give the axis

# %%
h['kiran']=9
h
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
#adding a column with values equal to length of dataframe
h['kumar']=range(0,h.shape[0])
h
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...
